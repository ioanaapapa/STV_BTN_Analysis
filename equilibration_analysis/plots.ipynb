# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import MDAnalysis as mda

# %%
def get_df(file,columns):
    datas = open(file,'r').readlines() #insert the path here

    data = []

    for line in datas[28:]:
        line = line.split()
        data.append([float(a) for a in line])

    df = pd.DataFrame(data)
    df.columns=columns
    return df

# %%
def plot(df1,df2,df3,df4,df5, column):
    time = df1["Time(ps)"]
    fig = plt.figure()
    fig, ax = plt.subplots()
    ax.plot(time, df1[column], label='1')
    ax.plot(time, df2[column], label='2')
    ax.plot(time, df3[column], label='3')
    ax.plot(time, df4[column], label='4')
    ax.plot(time, df5[column], label='5')
    ax.set_xlabel('Time(ps)')
    ax.set_ylabel(column)
    ax.legend()
    plt.grid()
    plt.show()
    plt.close()

# %% [markdown]
# # BIOTIN

# %%
ls BTN
# Out:
# em_BTN.edr  em_BTN.xvg  nvt1.xvg  nvt2.xvg  nvt3.xvg  nvt4.xvg  nvt5.xvg

# %% [markdown]
# ### Energy Minimization

# %%
datas = open('BTN/em_BTN.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[24:]:
    line = line.split()
    data.append([float(a) for a in line])

df_em_BTN = pd.DataFrame(data)
df_em_BTN.columns = df_em_BTN.iloc[0]

# %%
df_em_BTN.columns=['Time(ps)', 'Potential Energy(kJ/mol)']
df_em_BTN
# Out:
#       Time(ps)  Potential Energy(kJ/mol)
# 0          0.0              1.503509e+06
# 1          1.0              1.256372e+06
# 2          2.0              9.373329e+05
# 3          3.0              6.501728e+05
# 4          4.0              4.265672e+05
# ...        ...                       ...
# 1048    1336.0             -8.987391e+05
# 1049    1337.0             -8.987392e+05
# 1050    1338.0             -8.987394e+05
# 1051    1340.0             -8.987398e+05
# 1052    1341.0             -8.987400e+05
#
# [1053 rows x 2 columns]

# %%
df_em_BTN.plot(x='Time(ps)',y='Potential Energy(kJ/mol)') #teal blue
# Out:
# <Axes: xlabel='Time(ps)'>

# %% [markdown]
# ### NVT equilibration - 0.5 ns

# %%
df_nvt1 = get_df('BTN/nvt1.xvg',["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Total Energy(kJ/mol)","Temperature(K)", "Pressure(bar)"])
df_nvt2= get_df('BTN/nvt2.xvg',["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Total Energy(kJ/mol)","Temperature(K)", "Pressure(bar)"])
df_nvt3 = get_df('BTN/nvt3.xvg',["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Total Energy(kJ/mol)","Temperature(K)", "Pressure(bar)"])
df_nvt4 = get_df('BTN/nvt4.xvg',["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Total Energy(kJ/mol)","Temperature(K)", "Pressure(bar)"])
df_nvt5 = get_df('BTN/nvt5.xvg',["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Total Energy(kJ/mol)","Temperature(K)", "Pressure(bar)"])

# %%
plot(df_nvt1,df_nvt2,df_nvt3,df_nvt4,df_nvt5,"Potential Energy(kJ/mol)")

# %%
plot(df_nvt1,df_nvt2,df_nvt3,df_nvt4,df_nvt5,"Kinetic Energy(kJ/mol)")

# %%
plot(df_nvt1,df_nvt2,df_nvt3,df_nvt4,df_nvt5,"Total Energy(kJ/mol)")

# %%
plot(df_nvt1,df_nvt2,df_nvt3,df_nvt4,df_nvt5,"Temperature(K)")

# %%
plot(df_nvt1,df_nvt2,df_nvt3,df_nvt4,df_nvt5,"Pressure(bar)")

# %%
df_npt1 = get_df('BTN/nvt1.xvg',["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Total Energy(kJ/mol)","Temperature(K)", "Pressure(bar)"])
df_npt2= get_df('BTN/nvt2.xvg',["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Total Energy(kJ/mol)","Temperature(K)", "Pressure(bar)"])
df_npt3 = get_df('BTN/nvt3.xvg',["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Total Energy(kJ/mol)","Temperature(K)", "Pressure(bar)"])
df_npt4 = get_df('BTN/nvt4.xvg',["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Total Energy(kJ/mol)","Temperature(K)", "Pressure(bar)"])
df_npt5 = get_df('BTN/nvt5.xvg',["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Total Energy(kJ/mol)","Temperature(K)", "Pressure(bar)"])

# %%
time = df_nvt1["Time(ps)"]
fig = plt.figure()
fig, ax = plt.subplots()
    ax.plot(time, array1, label='Rep. 1', color=colors[0])
    ax.plot(time, array2, label='Rep. 2', color=colors[1])
    ax.plot(time, array3, label='Rep. 3', color=colors[2])
    ax.plot(time, array4, label='Rep. 4', color=colors[3])
    ax.plot(time, array5, label='Rep. 5', color=colors[4])
    ax.set_xlabel('Time (ps)')
    ax.set_ylabel(parameter)
    ax.set_xlim([0,50000])
    ax.set_title(title)
    #ax.set_ylim([inf_limit,sup_limit])
    ax.legend()
    plt.savefig('ligand_ligand_rmsd.png')               
    plt.close()
    plt.show()

# %%
df_nvt1.plot(x="Time(ps)",y="Potential Energy(kJ/mol)", color=colors[0])
# Out:
# <AxesSubplot:xlabel='Time(ps)'>

# %%
df_nvt_eq1["Potential Energy(kJ/mol)"][50:].mean()
# Out:
# -2823652.2913105413

# %%
df_nvt_eq1.plot(x="Time(ps)",y="Kinetic Energy(kJ/mol)", color=colors[0])
# Out:
# <AxesSubplot:xlabel='Time(ps)'>

# %%
df_nvt_eq1["Kinetic Energy(kJ/mol)"][50:].mean()
# Out:
# 407808.286502849

# %%
df_nvt_eq1.plot(x="Time(ps)",y="Temperature(K)", color=colors[0])
# Out:
# <AxesSubplot:xlabel='Time(ps)'>

# %%
df_nvt_eq1["Temperature(K)"][50:].mean()
# Out:
# 298.0141502535613

# %%
datas = open('rep_1/nvt_eq_rmsd.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[18:]:
    line = line.split()
    data.append([float(a) for a in line])

df_rmsd_nvt1 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_rmsd_nvt1.columns=["Time(ps)","RMSD (nm)"]

# %% [markdown]
# df_rmsd_nvt1

# %%
df_rmsd_nvt1.plot(x="Time(ps)",y="RMSD (nm)", color=colors[0])
# Out:
# <AxesSubplot:xlabel='Time(ps)'>

# %%
df_rmsd_nvt1["RMSD (nm)"][350:].mean()
# Out:
# 0.13738234117647063

# %% [markdown]
# ### NPT equilibration - 12 ns

# %%
datas = open('rep_1/npt_eq.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[28:]:
    line = line.split()
    data.append([float(a) for a in line])

df_npt_eq1 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_npt_eq1.columns=["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Temperature(K)", "Pressure (bar)", "Density (kg/m^3)"]

# %%
df_npt_eq1
# Out:
#        Time(ps)  Potential Energy(kJ/mol)  Kinetic Energy(kJ/mol)  \
# 0           0.0               -2824437.75            412424.78125
# 1           0.5               -2822332.50            406827.62500
# 2           1.0               -2826378.50            406541.93750
# 3           1.5               -2827021.25            407666.34375
# 4           2.0               -2824458.75            408469.31250
# ...         ...                       ...                     ...
# 23996   11998.0               -2826154.00            408809.71875
# 23997   11998.5               -2826215.50            407219.00000
# 23998   11999.0               -2823947.50            406045.81250
# 23999   11999.5               -2827813.25            406810.87500
# 24000   12000.0               -2826299.75            407186.93750
#
#        Temperature(K)  Pressure (bar)  Density (kg/m^3)
# 0          301.387756     -307.792847        986.348022
# 1          297.297546      -43.016174        991.602234
# ...

# %%
df_npt_eq1.plot(x="Time(ps)",y="Potential Energy(kJ/mol)", color=colors[0])
# Out:
# <AxesSubplot:xlabel='Time(ps)'>

# %%
df_npt_eq1["Potential Energy(kJ/mol)"][2000:].mean()
# Out:
# -2825540.5597700104

# %%
df_npt_eq1.plot(x="Time(ps)",y="Kinetic Energy(kJ/mol)", color=colors[0])
# Out:
# <AxesSubplot:xlabel='Time(ps)'>

# %%
df_npt_eq1["Kinetic Energy(kJ/mol)"][2000:].mean()
# Out:
# 407792.61920907005

# %%
df_npt_eq1.plot(x="Time(ps)",y="Temperature(K)", color=colors[0])
# Out:
# <AxesSubplot:xlabel='Time(ps)'>

# %%
df_npt_eq1["Temperature(K)"][2000:].mean()
# Out:
# 298.00270169705925

# %%
df_npt_eq1.plot(x="Time(ps)",y="Pressure (bar)", color=colors[0])
# Out:
# <AxesSubplot:xlabel='Time(ps)'>

# %%
df_npt_eq1["Pressure (bar)"][2000:].mean()
# Out:
# 1.3703527421480841

# %%
df_npt_eq1.plot(x="Time(ps)",y="Density (kg/m^3)", color=colors[0])
# Out:
# <AxesSubplot:xlabel='Time(ps)'>

# %%
df_npt_eq1["Density (kg/m^3)"][2000:].mean()
# Out:
# 996.9050366037453

# %%
datas = open('rep_1/npt_eq_rmsd.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[18:]:
    line = line.split()
    data.append([float(a) for a in line])

df_rmsd_npt1 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_rmsd_npt1.columns=["Time(ps)","RMSD (nm)"]

# %%
df_rmsd_npt1
# Out:
#        Time(ps)  RMSD (nm)
# 0           0.0   0.000000
# 1           0.5   0.033368
# 2           1.0   0.056540
# 3           1.5   0.050884
# 4           2.0   0.063882
# ...         ...        ...
# 23996   11998.0   0.190565
# 23997   11998.5   0.180453
# 23998   11999.0   0.169997
# 23999   11999.5   0.164840
# 24000   12000.0   0.166230
#
# [24001 rows x 2 columns]

# %%
df_rmsd_npt1.plot(x="Time(ps)",y="RMSD (nm)", color=colors[0])
# Out:
# <AxesSubplot:xlabel='Time(ps)'>

# %%
df_rmsd_npt1["RMSD (nm)"][2000:].mean()
# Out:
# 0.13192496842416254

# %% [markdown]
# ### Production - 50 ns

# %%
datas = open('rep_1/prod.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[28:]:
    line = line.split()
    data.append([float(a) for a in line])

df_prod1 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_prod1.columns=["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Temperature(K)", "Pressure (bar)", "Density (kg/m^3)"]

# %%
df_prod1
# Out:
#         Time(ps)  Potential Energy(kJ/mol)  Kinetic Energy(kJ/mol)  \
# 0            0.0               -2826194.50            413808.34375
# 1            0.5               -2827349.00            408432.84375
# 2            1.0               -2828213.25            409224.56250
# 3            1.5               -2825793.50            408823.96875
# 4            2.0               -2828492.50            408311.12500
# ...          ...                       ...                     ...
# 99996    49998.0               -2824806.00            407787.00000
# 99997    49998.5               -2825462.25            407809.62500
# 99998    49999.0               -2826010.50            407066.68750
# 99999    49999.5               -2825687.50            408156.93750
# 100000   50000.0               -2828510.75            408182.34375
#
#         Temperature(K)  Pressure (bar)  Density (kg/m^3)
# 0           302.398804     -136.480240        996.634766
# ...

# %%
df_prod1.plot(x="Time(ps)",y="Potential Energy(kJ/mol)", color=colors[0])
# Out:
# <AxesSubplot:xlabel='Time(ps)'>

# %%
df_prod1["Potential Energy(kJ/mol)"].mean()
# Out:
# -2825614.874793752

# %%
df_prod1.plot(x="Time(ps)",y="Kinetic Energy(kJ/mol)", color=colors[0])
# Out:
# <AxesSubplot:xlabel='Time(ps)'>

# %%
df_prod1["Kinetic Energy(kJ/mol)"].mean()
# Out:
# 407797.9933194418

# %%
df_prod1.plot(x="Time(ps)",y="Temperature(K)", color=colors[0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 df_prod1.plot(x="Time(ps)",y="Temperature(K)", color=colors[0])
#
# File ~/anaconda3/envs/mdanalysis2.6.1/lib/python3.10/site-packages/pandas/plotting/_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/anaconda3/envs/mdanalysis2.6.1/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
df_prod1["Temperature(K)"].mean()

# %%
df_prod1.plot(x="Time(ps)",y="Pressure (bar)", color=colors[0])

# %%
df_prod1["Pressure (bar)"].mean()

# %%
df_prod1.plot(x="Time(ps)",y="Density (kg/m^3)", color=colors[0])

# %%
df_prod1["Density (kg/m^3)"].mean()

# %%
datas = open('rep_1/prod_BTN_rmsd.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[18:]:
    line = line.split()
    data.append([float(a) for a in line])

df_rmsd_prod1 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_rmsd_prod1.columns=["Time(ps)","RMSD (nm)"]

# %%
df_rmsd_prod1

# %%
df_rmsd_prod1.plot(x="Time(ps)",y="RMSD (nm)", color=colors[0])

# %%
df_rmsd_prod1["RMSD (nm)"].mean()

# %% [markdown]
# ### Entropy calculation - with previous CodeEntropy release

# %%
tprfile1 = "rep_1/prod_BTN_only.tpr"
trrfile1 = "rep_1/prod_BTN_only.trr"
u1 = mda.Universe(tprfile1, trrfile1)

# %%
from CodeEntropy.ClassCollection import DataContainer as DC
dataContainer = DC.DataContainer (u1)
# Out:
# Traceback (most recent call last):
#
#   File "/home/ioana/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "/tmp/ipykernel_23994/3269246337.py", line 1, in <module>
#     from CodeEntropy.ClassCollection import DataContainer as DC
#
#   File "/home/ioana/Desktop/STFC/CodeEntropy/code/CodeEntropy/CodeEntropy/ClassCollection/DataContainer.py", line 5, in <module>
#     from CodeEntropy.ClassCollection import BondStructs
#
#   File "/home/ioana/Desktop/STFC/CodeEntropy/code/CodeEntropy/CodeEntropy/ClassCollection/BondStructs.py", line 7, in <module>
#     from CodeEntropy.FunctionCollection import GeometricFunctions as GF
#
#   File "/home/ioana/Desktop/STFC/CodeEntropy/code/CodeEntropy/CodeEntropy/FunctionCollection/GeometricFunctions.py", line 30
#     return list_of_beads
#     ^
# SyntaxError: invalid syntax

# %%
num_frames = len(dataContainer.trajSnapshots)
print(num_frames)
# Out:
# 100001

# %%
dataContainer

# %%
from CodeEntropy.FunctionCollection import EntropyFunctions as EF
selection_string = "all"
axis_list = ["N2","C4","C2"]
outFile = None
moutFile = None
nmdFile = None
csv_out = None
tScale = 1.0
fScale = 1.0
temper = 298.0
verbose = 3 
thread = 4

# %%
wm_entropyFF1, wm_entropyTT1 = EF.compute_entropy_whole_molecule_level (
    arg_hostDataContainer = dataContainer,
    arg_outFile = outFile,
    arg_selector = selection_string,
    arg_moutFile = moutFile,
    arg_nmdFile = nmdFile,
    arg_fScale = fScale,
    arg_tScale = tScale,
    arg_temper = temper,
    arg_verbose = verbose
)
print (f"wm_entropyFF = {wm_entropyFF1}")
print(f"wm_entropyTT = {wm_entropyTT1}")

# %%
UA_entropyFF1, UA_entropyTT1, res_df = EF.compute_entropy_UA_level (
    arg_hostDataContainer = dataContainer,
    arg_outFile = outFile,
    arg_selector = selection_string,
    arg_moutFile = moutFile,
    arg_nmdFile = nmdFile,
    arg_fScale = fScale,
    arg_tScale = tScale,
    arg_temper = temper,
    arg_verbose = verbose,
    arg_axis_list = axis_list,
    arg_csv_out = csv_out,
)
print (f"UA_res_entropyFF = {UA_entropyFF1}")
print(f"UA_entropyTT = {UA_entropyTT1}")
# Out:
# ------------------------------------------------------------
#             Hierarchy level. --> United Atom <--
# ------------------------------------------------------------
# Working on resid : BTN1
# Total number of UA beads in residue BTN1 : 16
# Assigning Translation Axes at the UA level-> Done
# Assigning Rotational Axes at the UA level-> Done
# Updating Local forces-> Done
# Updating Local torques-> Done
# Weighting forces and torques-> Done
# Updating the submatrices ...
# Finished updating submatrix FF
# Finished updating submatrix TT
# Done
# Generating Quadrants-> Done
# A shape change has occured (48,48) -> (25, 25)
# Diagonalizing-> Done
# Changing the units of eigen values to SI units-> Done
# Sorting spectrum in ascending order of frequencies-> Done
# Entropy values:
# FF Entropy (UA for BTN1)                 : 109.8780 J/mol/K
# TT Entropy (UA for BTN1)                 : 15.0502 J/mol/K
#
#
#
# ------------------------------------------------------------
# ...

# %%
result_entropyAEM1 = EF.compute_topographical_entropy_AEM(
    arg_hostDataContainer = dataContainer,
    arg_selector = selection_string,
    arg_outFile = outFile,
    arg_verbose = verbose
)
print(f"result_entropyAEM = {result_entropyAEM1}")

# %%
total1 = wm_entropyFF1 + wm_entropyTT1 + UA_entropyFF1 + UA_entropyTT1 + result_entropyAEM1
print(f"Total Entropy = {total1} J/mol/K")

# %% [markdown]
# ## REP 2

# %% [markdown]
# ### Energy Minimization

# %%
datas = open('rep_2/em.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[24:]:
    line = line.split()
    data.append([float(a) for a in line])

df_em2 = pd.DataFrame(data)
df_em2.columns = df_em1.iloc[0]

# %%
df_em2.columns=['Time(ps)', 'Potential Energy(kJ/mol)']
df_em2

# %%
df_em2.plot(x='Time(ps)',y='Potential Energy(kJ/mol)', color=colors[1])

# %% [markdown]
# ### NVT equilibration - 0.2 ns

# %%
datas = open('rep_2/nvt_eq.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[26:]:
    line = line.split()
    data.append([float(a) for a in line])

df_nvt_eq2 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_nvt_eq2.columns=["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Temperature(K)"]

# %%
df_nvt_eq2

# %%
df_nvt_eq2.plot(x="Time(ps)",y="Potential Energy(kJ/mol)", color=colors[1])

# %%
df_nvt_eq2["Potential Energy(kJ/mol)"][50:].mean()

# %%
df_nvt_eq2.plot(x="Time(ps)",y="Kinetic Energy(kJ/mol)", color=colors[1])

# %%
df_nvt_eq2["Kinetic Energy(kJ/mol)"][50:].mean()

# %%
df_nvt_eq2.plot(x="Time(ps)",y="Temperature(K)", color=colors[1])

# %%
df_nvt_eq2["Temperature(K)"][25:].mean()

# %%
datas = open('rep_2/nvt_eq_rmsd.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[18:]:
    line = line.split()
    data.append([float(a) for a in line])

df_rmsd_nvt2 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_rmsd_nvt2.columns=["Time(ps)","RMSD (nm)"]

# %%
df_rmsd_nvt2

# %%
df_rmsd_nvt2.plot(x="Time(ps)",y="RMSD (nm)", color=colors[1])

# %%
df_rmsd_nvt2["RMSD (nm)"][350:].mean()

# %% [markdown]
# ### NPT equilibration - 12 ns

# %%
datas = open('rep_2/npt_eq.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[28:]:
    line = line.split()
    data.append([float(a) for a in line])

df_npt_eq2 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_npt_eq2.columns=["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Temperature(K)", "Pressure (bar)", "Density (kg/m^3)"]

# %%
df_npt_eq2

# %%
df_npt_eq2.plot(x="Time(ps)",y="Potential Energy(kJ/mol)", color=colors[1])

# %%
df_npt_eq2["Potential Energy(kJ/mol)"][2000:].mean()

# %%
df_npt_eq2.plot(x="Time(ps)",y="Kinetic Energy(kJ/mol)", color=colors[1])

# %%
df_npt_eq2["Kinetic Energy(kJ/mol)"][2000:].mean()

# %%
df_npt_eq2.plot(x="Time(ps)",y="Temperature(K)", color=colors[1])

# %%
df_npt_eq2["Temperature(K)"][2000:].mean()

# %%
df_npt_eq2.plot(x="Time(ps)",y="Pressure (bar)", color=colors[1])

# %%
df_npt_eq2["Pressure (bar)"][2000:].mean()

# %%
df_npt_eq2.plot(x="Time(ps)",y="Density (kg/m^3)", color=colors[1])

# %%
df_npt_eq2["Density (kg/m^3)"][2000:].mean()

# %%
datas = open('rep_2/npt_eq_rmsd.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[18:]:
    line = line.split()
    data.append([float(a) for a in line])

df_rmsd_npt2 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_rmsd_npt2.columns=["Time(ps)","RMSD (nm)"]

# %%
df_rmsd_npt2

# %%
df_rmsd_npt2.plot(x="Time(ps)",y="RMSD (nm)", color=colors[1])

# %%
df_rmsd_npt2["RMSD (nm)"][2000:].mean()

# %% [markdown]
# ### Production - 50 ns

# %%
datas = open('rep_2/prod.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[28:]:
    line = line.split()
    data.append([float(a) for a in line])

df_prod2 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_prod2.columns=["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Temperature(K)", "Pressure (bar)", "Density (kg/m^3)"]

# %%
df_prod2

# %%
df_prod2.plot(x="Time(ps)",y="Potential Energy(kJ/mol)", color=colors[1])

# %%
df_prod2["Potential Energy(kJ/mol)"].mean()

# %%
df_prod2.plot(x="Time(ps)",y="Kinetic Energy(kJ/mol)", color=colors[1])

# %%
df_prod2["Kinetic Energy(kJ/mol)"].mean()

# %%
df_prod2.plot(x="Time(ps)",y="Temperature(K)", color=colors[1])

# %%
df_prod2["Temperature(K)"].mean()

# %%
df_prod2.plot(x="Time(ps)",y="Pressure (bar)", color=colors[1])

# %%
df_prod2["Pressure (bar)"].mean()

# %%
df_prod2.plot(x="Time(ps)",y="Density (kg/m^3)", color=colors[1])

# %%
df_prod2["Density (kg/m^3)"].mean()

# %%
datas = open('rep_2/prod_BTN_rmsd.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[18:]:
    line = line.split()
    data.append([float(a) for a in line])

df_rmsd_prod2 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_rmsd_prod2.columns=["Time(ps)","RMSD (nm)"]

# %%
df_rmsd_prod2

# %%
df_rmsd_prod2.plot(x="Time(ps)",y="RMSD (nm)", color=colors[1])

# %%
df_rmsd_prod2["RMSD (nm)"].mean()

# %% [markdown]
# ### Entropy calculation - with previous CodeEntropy release

# %%
tprfile2 = "rep_2/prod_BTN_only.tpr"
trrfile2 = "rep_2/prod_BTN_only.trr"
u2 = mda.Universe(tprfile2, trrfile2)

# %%
from CodeEntropy.ClassCollection import DataContainer as DC
dataContainer = DC.DataContainer (u2)
# Out:
# Number of atoms      : 31
# Number of frames     : 100001

# %%
num_frames = len(dataContainer.trajSnapshots)
print(num_frames)
# Out:
# 100001

# %%
dataContainer

# %%
from CodeEntropy.FunctionCollection import EntropyFunctions as EF
selection_string = "all"
outFile = None
moutFile = None
nmdFile = None
csv_out = None
tScale = 1.0
fScale = 1.0
temper = 298.0
axis_list = ["N2","C4","C2"]
verbose = 3 
thread = 4

# %%
wm_entropyFF2, wm_entropyTT2 = EF.compute_entropy_whole_molecule_level (
    arg_hostDataContainer = dataContainer,
    arg_outFile = outFile,
    arg_selector = selection_string,
    arg_moutFile = moutFile,
    arg_nmdFile = nmdFile,
    arg_fScale = fScale,
    arg_tScale = tScale,
    arg_temper = temper,
    arg_verbose = verbose
)
print (f"wm_entropyFF = {wm_entropyFF2}")
print(f"wm_entropyTT = {wm_entropyTT2}")
# Out:
# ------------------------------------------------------------
#           Hierarchy level. --> Whole molecule <--
# ------------------------------------------------------------
# Total number of beads at the whole molecule level = 1
# Assigning Translation and Rotation Axes @ whole molecule level-> Done
# Updating Local coordinates-> Done
# Updating Local forces-> Done
# Updating Local torques-> Done
# Weighting forces and torques-> Done
# Updating the submatrices ...
# Finished updating submatrix FF
# Finished updating submatrix TT
# Done
# Generating Quadrants-> Done
# Diagonalizing-> Done
# Changing the units of eigen values to SI units-> Done
# Sorting spectrum in ascending order of frequencies-> Done
# Entropy values:
# FF Entropy (Whole mol level)             : 41.4005 J/mol/K
# TT Entropy (Whole mol level)             : 36.2418 J/mol/K
# wm_entropyFF = 41.40054382409824
# wm_entropyTT = 36.24176685748883

# %%
UA_entropyFF2, UA_entropyTT2, res_df = EF.compute_entropy_UA_level (
    arg_hostDataContainer = dataContainer,
    arg_outFile = outFile,
    arg_selector = selection_string,
    arg_moutFile = moutFile,
    arg_nmdFile = nmdFile,
    arg_fScale = fScale,
    arg_tScale = tScale,
    arg_temper = temper,
    arg_verbose = verbose,
    arg_axis_list = axis_list,
    arg_csv_out = csv_out,
)
print (f"UA_res_entropyFF = {UA_entropyFF2}")
print(f"UA_entropyTT = {UA_entropyTT2}")
# Out:
# ------------------------------------------------------------
#             Hierarchy level. --> United Atom <--
# ------------------------------------------------------------
# Working on resid : BTN1
# Total number of UA beads in residue BTN1 : 16
# Assigning Translation Axes at the UA level-> Done
# Assigning Rotational Axes at the UA level-> Done
# Updating Local forces-> Done
# Updating Local torques-> Done
# Weighting forces and torques-> Done
# Updating the submatrices ...
# Finished updating submatrix FF
# Finished updating submatrix TT
# Done
# Generating Quadrants-> Done
# A shape change has occured (48,48) -> (25, 25)
# Diagonalizing-> Done
# Changing the units of eigen values to SI units-> Done
# Sorting spectrum in ascending order of frequencies-> Done
# Entropy values:
# FF Entropy (UA for BTN1)                 : 109.5310 J/mol/K
# TT Entropy (UA for BTN1)                 : 15.0698 J/mol/K
#
#
#
# ------------------------------------------------------------
# ...

# %%
result_entropyAEM2 = EF.compute_topographical_entropy_AEM(
    arg_hostDataContainer = dataContainer,
    arg_selector = selection_string,
    arg_outFile = outFile,
    arg_verbose = verbose
)
print(f"result_entropyAEM = {result_entropyAEM2}")
# Out:
# ------------------------------------------------------------
# Topographical entropy of residue side chains
# computed using all the dihedrals with AEM method
# ------------------------------------------------------------
# ----------Working on resid : 1 (BTN)----------
# Found 14 exclusive dihedrals in residue BTN1
# Found 14 dihedrals which collectively acquire 128 unique conformers
# Residue Topographical Entropy from AEM (BTN 1) : 27.7552
# ------------------------------------------------------------
# Total Topog. Entropy (AEM)               :          27.755
# ------------------------------------------------------------
# result_entropyAEM = 27.755208469952546

# %%
total2 = wm_entropyFF2 + wm_entropyTT2 + UA_entropyFF2 + UA_entropyTT2 + result_entropyAEM2
print(f"Total Entropy = {total2} J/mol/K")
# Out:
# Total Entropy = 231.0419508042318 J/mol/K

# %% [markdown]
# ## REP 3

# %% [markdown]
# ### Energy Minimisation

# %%
datas = open('rep_3/em.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[24:]:
    line = line.split()
    data.append([float(a) for a in line])

df_em3 = pd.DataFrame(data)
df_em3.columns = df_em1.iloc[0]

# %%
df_em3.columns=['Time(ps)', 'Potential Energy(kJ/mol)']
df_em3

# %%
df_em3.plot(x='Time(ps)',y='Potential Energy(kJ/mol)', color=colors[2]) #green

# %% [markdown]
# ### NVT equilibration - 0.2 ns

# %%
datas = open('rep_3/nvt_eq.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[26:]:
    line = line.split()
    data.append([float(a) for a in line])

df_nvt_eq3 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_nvt_eq3.columns=["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Temperature(K)"]

# %%
df_nvt_eq3

# %%
df_nvt_eq3.plot(x="Time(ps)",y="Potential Energy(kJ/mol)", color=colors[2])

# %%
df_nvt_eq3["Potential Energy(kJ/mol)"][50:].mean()

# %%
df_nvt_eq3.plot(x="Time(ps)",y="Kinetic Energy(kJ/mol)", color=colors[2])

# %%
df_nvt_eq3["Kinetic Energy(kJ/mol)"][50:].mean()

# %%
df_nvt_eq3.plot(x="Time(ps)",y="Temperature(K)", color=colors[2])

# %%
df_nvt_eq3["Temperature(K)"][50:].mean()

# %%
datas = open('rep_3/nvt_eq_rmsd.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[18:]:
    line = line.split()
    data.append([float(a) for a in line])

df_rmsd_nvt3 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_rmsd_nvt3.columns=["Time(ps)","RMSD (nm)"]

# %%
df_rmsd_nvt3

# %%
df_rmsd_nvt3.plot(x="Time(ps)",y="RMSD (nm)", color=colors[2])

# %%
df_rmsd_nvt3["RMSD (nm)"][350:].mean()

# %% [markdown]
# ### NPT equilibration - 12 ns

# %%
datas = open('rep_3/npt_eq.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[28:]:
    line = line.split()
    data.append([float(a) for a in line])

df_npt_eq3 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_npt_eq3.columns=["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Temperature(K)", "Pressure (bar)", "Density (kg/m^3)"]

# %%
df_npt_eq3

# %%
df_npt_eq3.plot(x="Time(ps)",y="Potential Energy(kJ/mol)", color=colors[2])

# %%
df_npt_eq3["Potential Energy(kJ/mol)"][2000:].mean()

# %%
df_npt_eq3.plot(x="Time(ps)",y="Kinetic Energy(kJ/mol)", color=colors[2])

# %%
df_npt_eq3["Kinetic Energy(kJ/mol)"][2000:].mean()

# %%
df_npt_eq3.plot(x="Time(ps)",y="Temperature(K)", color=colors[2])

# %%
df_npt_eq3["Temperature(K)"][2000:].mean()

# %%
df_npt_eq3.plot(x="Time(ps)",y="Pressure (bar)", color=colors[2])

# %%
df_npt_eq3["Pressure (bar)"][2000:].mean()

# %%
df_npt_eq3.plot(x="Time(ps)",y="Density (kg/m^3)", color=colors[2])

# %%
df_npt_eq3["Density (kg/m^3)"][2000:].mean()

# %%
datas = open('rep_3/npt_eq_rmsd.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[18:]:
    line = line.split()
    data.append([float(a) for a in line])

df_rmsd_npt3 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_rmsd_npt3.columns=["Time(ps)","RMSD (nm)"]

# %%
df_rmsd_npt3

# %%
df_rmsd_npt3.plot(x="Time(ps)",y="RMSD (nm)", color=colors[2])

# %%
df_rmsd_npt3["RMSD (nm)"][2000:].mean()

# %% [markdown]
# ### Production - 50 ns

# %%
datas = open('rep_3/prod.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[28:]:
    line = line.split()
    data.append([float(a) for a in line])

df_prod3 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_prod3.columns=["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Temperature(K)", "Pressure (bar)", "Density (kg/m^3)"]

# %%
df_prod3

# %%
df_prod3.plot(x="Time(ps)",y="Potential Energy(kJ/mol)", color=colors[2])

# %%
df_prod3["Potential Energy(kJ/mol)"].mean()

# %%
df_prod3.plot(x="Time(ps)",y="Kinetic Energy(kJ/mol)", color=colors[2])

# %%
df_prod3["Kinetic Energy(kJ/mol)"].mean()

# %%
df_prod3.plot(x="Time(ps)",y="Temperature(K)", color=colors[2])

# %%
df_prod3["Temperature(K)"].mean()

# %%
df_prod3.plot(x="Time(ps)",y="Pressure (bar)", color=colors[2])

# %%
df_prod3["Pressure (bar)"].mean()

# %%
df_prod3.plot(x="Time(ps)",y="Density (kg/m^3)", color=colors[2])

# %%
df_prod3["Density (kg/m^3)"].mean()

# %%
datas = open('rep_3/prod_BTN_rmsd.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[18:]:
    line = line.split()
    data.append([float(a) for a in line])

df_rmsd_prod3 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_rmsd_prod3.columns=["Time(ps)","RMSD (nm)"]

# %%
df_rmsd_prod3

# %%
df_rmsd_prod3.plot(x="Time(ps)",y="RMSD (nm)", color=colors[2])

# %%
df_rmsd_prod3["RMSD (nm)"].mean()

# %% [markdown]
# ### Entropy calculation - with previous CodeEntropy release

# %%
tprfile3 = "rep_3/prod_BTN_only.tpr"
trrfile3 = "rep_3/prod_BTN_only.trr"
u3 = mda.Universe(tprfile3, trrfile3)

# %%
from CodeEntropy.ClassCollection import DataContainer as DC
dataContainer = DC.DataContainer (u3)
# Out:
# Number of atoms      : 31
# Number of frames     : 100001

# %%
num_frames = len(dataContainer.trajSnapshots)
print(num_frames)
# Out:
# 100001

# %%
dataContainer

# %%
from CodeEntropy.FunctionCollection import EntropyFunctions as EF
selection_string = "all"
axis_list = ["N2","C4","C2"]
outFile = None
moutFile = None
nmdFile = None
csv_out = None
tScale = 1.0
fScale = 1.0
temper = 298.0 
verbose = 3 
thread = 4

# %%
wm_entropyFF3, wm_entropyTT3 = EF.compute_entropy_whole_molecule_level (
    arg_hostDataContainer = dataContainer,
    arg_outFile = outFile,
    arg_selector = selection_string,
    arg_moutFile = moutFile,
    arg_nmdFile = nmdFile,
    arg_fScale = fScale,
    arg_tScale = tScale,
    arg_temper = temper,
    arg_verbose = verbose
)
print (f"wm_entropyFF = {wm_entropyFF3}")
print(f"wm_entropyTT = {wm_entropyTT3}")
# Out:
# ------------------------------------------------------------
#           Hierarchy level. --> Whole molecule <--
# ------------------------------------------------------------
# Total number of beads at the whole molecule level = 1
# Assigning Translation and Rotation Axes @ whole molecule level-> Done
# Updating Local coordinates-> Done
# Updating Local forces-> Done
# Updating Local torques-> Done
# Weighting forces and torques-> Done
# Updating the submatrices ...
# Finished updating submatrix FF
# Finished updating submatrix TT
# Done
# Generating Quadrants-> Done
# Diagonalizing-> Done
# Changing the units of eigen values to SI units-> Done
# Sorting spectrum in ascending order of frequencies-> Done
# Entropy values:
# FF Entropy (Whole mol level)             : 41.4019 J/mol/K
# TT Entropy (Whole mol level)             : 36.2140 J/mol/K
# wm_entropyFF = 41.401896772937
# wm_entropyTT = 36.21395436787566

# %%
UA_entropyFF3, UA_entropyTT3, res_df = EF.compute_entropy_UA_level (
    arg_hostDataContainer = dataContainer,
    arg_outFile = outFile,
    arg_selector = selection_string,
    arg_moutFile = moutFile,
    arg_nmdFile = nmdFile,
    arg_fScale = fScale,
    arg_tScale = tScale,
    arg_temper = temper,
    arg_verbose = verbose,
    arg_axis_list = axis_list,
    arg_csv_out = csv_out,
)
print (f"UA_res_entropyFF = {UA_entropyFF3}")
print(f"UA_entropyTT = {UA_entropyTT3}")
# Out:
# ------------------------------------------------------------
#             Hierarchy level. --> United Atom <--
# ------------------------------------------------------------
# Working on resid : BTN1
# Total number of UA beads in residue BTN1 : 16
# Assigning Translation Axes at the UA level-> Done
# Assigning Rotational Axes at the UA level-> Done
# Updating Local forces-> Done
# Updating Local torques-> Done
# Weighting forces and torques-> Done
# Updating the submatrices ...
# Finished updating submatrix FF
# Finished updating submatrix TT
# Done
# Generating Quadrants-> Done
# A shape change has occured (48,48) -> (25, 25)
# Diagonalizing-> Done
# Changing the units of eigen values to SI units-> Done
# Sorting spectrum in ascending order of frequencies-> Done
# Entropy values:
# FF Entropy (UA for BTN1)                 : 109.5784 J/mol/K
# TT Entropy (UA for BTN1)                 : 15.0739 J/mol/K
#
#
#
# ------------------------------------------------------------
# ...

# %%
result_entropyAEM3 = EF.compute_topographical_entropy_AEM(
    arg_hostDataContainer = dataContainer,
    arg_selector = selection_string,
    arg_outFile = outFile,
    arg_verbose = verbose
)
print(f"result_entropyAEM = {result_entropyAEM3}")
# Out:
# ------------------------------------------------------------
# Topographical entropy of residue side chains
# computed using all the dihedrals with AEM method
# ------------------------------------------------------------
# ----------Working on resid : 1 (BTN)----------
# Found 14 exclusive dihedrals in residue BTN1
# Found 14 dihedrals which collectively acquire 132 unique conformers
# Residue Topographical Entropy from AEM (BTN 1) : 28.1657
# ------------------------------------------------------------
# Total Topog. Entropy (AEM)               :          28.166
# ------------------------------------------------------------
# result_entropyAEM = 28.165729922632043

# %%
total3 = wm_entropyFF3 + wm_entropyTT3 + UA_entropyFF3 + UA_entropyTT3 + result_entropyAEM3
print(f"Total Entropy = {total3} J/mol/K")
# Out:
# Total Entropy = 231.49672328400737 J/mol/K

# %% [markdown]
# ## REP 4

# %% [markdown]
# ### Energy Minimization

# %%
datas = open('rep_4/em.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[24:]:
    line = line.split()
    data.append([float(a) for a in line])

df_em4 = pd.DataFrame(data)
df_em4.columns = df_em1.iloc[0]

# %%
df_em4.columns=['Time(ps)', 'Potential Energy(kJ/mol)']
df_em4

# %%
df_em4.plot(x='Time(ps)',y='Potential Energy(kJ/mol)', color=colors[3]) #teal blue

# %% [markdown]
# ### NVT equilibration - 0.2 ns

# %%
datas = open('rep_4/nvt_eq.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[26:]:
    line = line.split()
    data.append([float(a) for a in line])

df_nvt_eq4 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_nvt_eq4.columns=["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Temperature(K)"]

# %%
df_nvt_eq4

# %%
df_nvt_eq4.plot(x="Time(ps)",y="Potential Energy(kJ/mol)", color=colors[3])

# %%
df_nvt_eq4["Potential Energy(kJ/mol)"][50:].mean()

# %%
df_nvt_eq4.plot(x="Time(ps)",y="Kinetic Energy(kJ/mol)", color=colors[3])

# %%
df_nvt_eq4["Kinetic Energy(kJ/mol)"][50:].mean()

# %%
df_nvt_eq4.plot(x="Time(ps)",y="Temperature(K)", color=colors[3])

# %%
df_nvt_eq4["Temperature(K)"][100:].mean()

# %%
datas = open('rep_4/nvt_eq_rmsd.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[18:]:
    line = line.split()
    data.append([float(a) for a in line])

df_rmsd_nvt4 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_rmsd_nvt4.columns=["Time(ps)","RMSD (nm)"]

# %%
df_rmsd_nvt4

# %%
df_rmsd_nvt4.plot(x="Time(ps)",y="RMSD (nm)", color=colors[3])

# %%
df_rmsd_nvt4["RMSD (nm)"][350:].mean()

# %% [markdown]
# ### NPT equilibration - 12 ns

# %%
datas = open('rep_4/npt_eq.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[28:]:
    line = line.split()
    data.append([float(a) for a in line])

df_npt_eq4 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_npt_eq4.columns=["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Temperature(K)", "Pressure (bar)", "Density (kg/m^3)"]

# %%
df_npt_eq4

# %%
df_npt_eq4.plot(x="Time(ps)",y="Potential Energy(kJ/mol)", color=colors[3])

# %%
df_npt_eq4["Potential Energy(kJ/mol)"][2000:].mean()

# %%
df_npt_eq4.plot(x="Time(ps)",y="Kinetic Energy(kJ/mol)", color=colors[3])

# %%
df_npt_eq4["Kinetic Energy(kJ/mol)"][2000:].mean()

# %%
df_npt_eq4.plot(x="Time(ps)",y="Temperature(K)", color=colors[3])

# %%
df_npt_eq4["Temperature(K)"][2000:].mean()

# %%
df_npt_eq4.plot(x="Time(ps)",y="Pressure (bar)", color=colors[3])

# %%
df_npt_eq4["Pressure (bar)"][2000:].mean()

# %%
df_npt_eq4.plot(x="Time(ps)",y="Density (kg/m^3)", color=colors[3])

# %%
df_npt_eq4["Density (kg/m^3)"][2000:].mean()

# %%
datas = open('rep_4/npt_eq_rmsd.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[18:]:
    line = line.split()
    data.append([float(a) for a in line])

df_rmsd_npt4 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_rmsd_npt4.columns=["Time(ps)","RMSD (nm)"]

# %%
df_rmsd_npt4

# %%
df_rmsd_npt4.plot(x="Time(ps)",y="RMSD (nm)", color=colors[3])

# %%
df_rmsd_npt4["RMSD (nm)"][2000:].mean()

# %% [markdown]
# ### Production - 50 ns

# %%
datas = open('rep_4/prod.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[28:]:
    line = line.split()
    data.append([float(a) for a in line])

df_prod4 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_prod4.columns=["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Temperature(K)", "Pressure (bar)", "Density (kg/m^3)"]

# %%
df_prod4

# %%
df_prod4.plot(x="Time(ps)",y="Potential Energy(kJ/mol)", color=colors[3])

# %%
df_prod4["Potential Energy(kJ/mol)"].mean()

# %%
df_prod4.plot(x="Time(ps)",y="Kinetic Energy(kJ/mol)", color=colors[3])

# %%
df_prod4["Kinetic Energy(kJ/mol)"].mean()

# %%
df_prod4.plot(x="Time(ps)",y="Temperature(K)", color=colors[3])

# %%
df_prod4["Temperature(K)"].mean()

# %%
df_prod4.plot(x="Time(ps)",y="Pressure (bar)", color=colors[3])

# %%
df_prod4["Pressure (bar)"].mean()

# %%
df_prod4.plot(x="Time(ps)",y="Density (kg/m^3)", color=colors[3])

# %%
df_prod4["Density (kg/m^3)"].mean()

# %%
datas = open('rep_4/prod_BTN_rmsd.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[18:]:
    line = line.split()
    data.append([float(a) for a in line])

df_rmsd_prod4 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_rmsd_prod4.columns=["Time(ps)","RMSD (nm)"]

# %%
df_rmsd_prod4

# %%
df_rmsd_prod4.plot(x="Time(ps)",y="RMSD (nm)", color=colors[3])

# %%
df_rmsd_prod4["RMSD (nm)"].mean()

# %% [markdown]
# ### Entropy calculation - with previous CodeEntropy release

# %%
tprfile4 = "rep_4/prod_BTN_only.tpr"
trrfile4 = "rep_4/prod_BTN_only.trr"
u4 = mda.Universe(tprfile4, trrfile4)

# %%
from CodeEntropy.ClassCollection import DataContainer as DC
dataContainer = DC.DataContainer (u4)
# Out:
# Number of atoms      : 31
# Number of frames     : 100001

# %%
num_frames = len(dataContainer.trajSnapshots)
print(num_frames)
# Out:
# 100001

# %%
dataContainer

# %%
from CodeEntropy.FunctionCollection import EntropyFunctions as EF
selection_string = "all"
axis_list = ["N2","C4","C2"]
outFile = None
moutFile = None
nmdFile = None
csv_out = None
tScale = 1.0
fScale = 1.0
temper = 298.0 
verbose = 3 
thread = 4

# %%
wm_entropyFF4, wm_entropyTT4 = EF.compute_entropy_whole_molecule_level (
    arg_hostDataContainer = dataContainer,
    arg_outFile = outFile,
    arg_selector = selection_string,
    arg_moutFile = moutFile,
    arg_nmdFile = nmdFile,
    arg_fScale = fScale,
    arg_tScale = tScale,
    arg_temper = temper,
    arg_verbose = verbose
)
print (f"wm_entropyFF = {wm_entropyFF4}")
print(f"wm_entropyTT = {wm_entropyTT4}")
# Out:
# ------------------------------------------------------------
#           Hierarchy level. --> Whole molecule <--
# ------------------------------------------------------------
# Total number of beads at the whole molecule level = 1
# Assigning Translation and Rotation Axes @ whole molecule level-> Done
# Updating Local coordinates-> Done
# Updating Local forces-> Done
# Updating Local torques-> Done
# Weighting forces and torques-> Done
# Updating the submatrices ...
# Finished updating submatrix FF
# Finished updating submatrix TT
# Done
# Generating Quadrants-> Done
# Diagonalizing-> Done
# Changing the units of eigen values to SI units-> Done
# Sorting spectrum in ascending order of frequencies-> Done
# Entropy values:
# FF Entropy (Whole mol level)             : 41.3645 J/mol/K
# TT Entropy (Whole mol level)             : 36.1757 J/mol/K
# wm_entropyFF = 41.36451694048826
# wm_entropyTT = 36.17573400239581

# %%
UA_entropyFF4, UA_entropyTT4, res_df = EF.compute_entropy_UA_level (
    arg_hostDataContainer = dataContainer,
    arg_outFile = outFile,
    arg_selector = selection_string,
    arg_moutFile = moutFile,
    arg_nmdFile = nmdFile,
    arg_fScale = fScale,
    arg_tScale = tScale,
    arg_temper = temper,
    arg_verbose = verbose,
    arg_axis_list = axis_list,
    arg_csv_out = csv_out,
)
print (f"UA_res_entropyFF = {UA_entropyFF4}")
print(f"UA_entropyTT = {UA_entropyTT4}")
# Out:
# ------------------------------------------------------------
#             Hierarchy level. --> United Atom <--
# ------------------------------------------------------------
# Working on resid : BTN1
# Total number of UA beads in residue BTN1 : 16
# Assigning Translation Axes at the UA level-> Done
# Assigning Rotational Axes at the UA level-> Done
# Updating Local forces-> Done
# Updating Local torques-> Done
# Weighting forces and torques-> Done
# Updating the submatrices ...
# Finished updating submatrix FF
# Finished updating submatrix TT
# Done
# Generating Quadrants-> Done
# A shape change has occured (48,48) -> (25, 25)
# Diagonalizing-> Done
# Changing the units of eigen values to SI units-> Done
# Sorting spectrum in ascending order of frequencies-> Done
# Entropy values:
# FF Entropy (UA for BTN1)                 : 109.7028 J/mol/K
# TT Entropy (UA for BTN1)                 : 15.1437 J/mol/K
#
#
#
# ------------------------------------------------------------
# ...

# %%
result_entropyAEM4 = EF.compute_topographical_entropy_AEM(
    arg_hostDataContainer = dataContainer,
    arg_selector = selection_string,
    arg_outFile = outFile,
    arg_verbose = verbose
)
print(f"result_entropyAEM = {result_entropyAEM4}")
# Out:
# ------------------------------------------------------------
# Topographical entropy of residue side chains
# computed using all the dihedrals with AEM method
# ------------------------------------------------------------
# ----------Working on resid : 1 (BTN)----------
# Found 14 exclusive dihedrals in residue BTN1
# Found 14 dihedrals which collectively acquire 121 unique conformers
# Residue Topographical Entropy from AEM (BTN 1) : 27.2245
# ------------------------------------------------------------
# Total Topog. Entropy (AEM)               :          27.225
# ------------------------------------------------------------
# result_entropyAEM = 27.224521237584554

# %%
total4 = wm_entropyFF4 + wm_entropyTT4 + UA_entropyFF4 + UA_entropyTT4 + result_entropyAEM4
print(f"Total Entropy = {total4} J/mol/K")
# Out:
# Total Entropy = 230.65411452927214 J/mol/K

# %% [markdown]
# ## REP 5

# %% [markdown]
# ### Energy Minimization

# %%
datas = open('rep_5/em.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[24:]:
    line = line.split()
    data.append([float(a) for a in line])

df_em5 = pd.DataFrame(data)
df_em5.columns = df_em1.iloc[0]

# %%
df_em5.columns=['Time(ps)', 'Potential Energy(kJ/mol)']
df_em5

# %%
df_em5.plot(x='Time(ps)',y='Potential Energy(kJ/mol)', color=colors[4])

# %% [markdown]
# ### NVT equilibration - 0.2 ns

# %%
datas = open('rep_5/nvt_eq.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[26:]:
    line = line.split()
    data.append([float(a) for a in line])

df_nvt_eq5 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_nvt_eq5.columns=["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Temperature(K)"]

# %%
df_nvt_eq5

# %%
df_nvt_eq5.plot(x="Time(ps)",y="Potential Energy(kJ/mol)", color=colors[4])

# %%
df_nvt_eq5["Potential Energy(kJ/mol)"][50].mean()

# %%
df_nvt_eq5.plot(x="Time(ps)",y="Kinetic Energy(kJ/mol)", color=colors[4])

# %%
df_nvt_eq5["Kinetic Energy(kJ/mol)"][50].mean()

# %%
df_nvt_eq5.plot(x="Time(ps)",y="Temperature(K)", color=colors[4])

# %%
df_nvt_eq5["Temperature(K)"][100].mean()

# %%
datas = open('rep_5/nvt_eq_rmsd.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[18:]:
    line = line.split()
    data.append([float(a) for a in line])

df_rmsd_nvt5 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_rmsd_nvt5.columns=["Time(ps)","RMSD (nm)"]

# %%
df_rmsd_nvt5

# %%
df_rmsd_nvt5.plot(x="Time(ps)",y="RMSD (nm)", color=colors[4])

# %%
df_rmsd_nvt5["RMSD (nm)"][350].mean()

# %% [markdown]
# ### NPT equilibration - 12 ns

# %%
datas = open('rep_5/npt_eq.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[28:]:
    line = line.split()
    data.append([float(a) for a in line])

df_npt_eq5 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_npt_eq5.columns=["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Temperature(K)", "Pressure (bar)", "Density (kg/m^3)"]

# %%
df_npt_eq5

# %%
df_npt_eq5.plot(x="Time(ps)",y="Potential Energy(kJ/mol)", color=colors[4])

# %%
df_npt_eq5["Potential Energy(kJ/mol)"][2000:].mean()

# %%
df_npt_eq5.plot(x="Time(ps)",y="Kinetic Energy(kJ/mol)", color=colors[4])

# %%
df_npt_eq5["Kinetic Energy(kJ/mol)"][2000:].mean()

# %%
df_npt_eq5.plot(x="Time(ps)",y="Temperature(K)", color=colors[4])

# %%
df_npt_eq5["Temperature(K)"][2000:].mean()

# %%
df_npt_eq5.plot(x="Time(ps)",y="Pressure (bar)", color=colors[4])

# %%
df_npt_eq5["Pressure (bar)"][2000:].mean()

# %%
df_npt_eq5.plot(x="Time(ps)",y="Density (kg/m^3)", color=colors[4])

# %%
df_npt_eq5["Density (kg/m^3)"][2000:].mean()

# %%
datas = open('rep_5/npt_eq_rmsd.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[18:]:
    line = line.split()
    data.append([float(a) for a in line])

df_rmsd_npt5 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_rmsd_npt5.columns=["Time(ps)","RMSD (nm)"]

# %%
df_rmsd_npt5

# %%
df_rmsd_npt5.plot(x="Time(ps)",y="RMSD (nm)", color=colors[4])

# %%
df_rmsd_npt5["RMSD (nm)"][2000:].mean()

# %% [markdown]
# ### Production - 50 ns

# %%
datas = open('rep_5/prod.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[28:]:
    line = line.split()
    data.append([float(a) for a in line])

df_prod5 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_prod5.columns=["Time(ps)","Potential Energy(kJ/mol)","Kinetic Energy(kJ/mol)","Temperature(K)", "Pressure (bar)", "Density (kg/m^3)"]

# %%
df_prod5

# %%
df_prod5.plot(x="Time(ps)",y="Potential Energy(kJ/mol)", color=colors[4])

# %%
df_prod5["Potential Energy(kJ/mol)"].mean()

# %%
df_prod5.plot(x="Time(ps)",y="Kinetic Energy(kJ/mol)", color=colors[4])

# %%
df_prod5["Kinetic Energy(kJ/mol)"].mean()

# %%
df_prod5.plot(x="Time(ps)",y="Temperature(K)", color=colors[4])

# %%
df_prod5["Temperature(K)"].mean()

# %%
df_prod5.plot(x="Time(ps)",y="Pressure (bar)", color=colors[4])

# %%
df_prod5["Pressure (bar)"].mean()

# %%
df_prod5.plot(x="Time(ps)",y="Density (kg/m^3)", color=colors[4])

# %%
df_prod5["Density (kg/m^3)"].mean()

# %%
datas = open('rep_5/prod_BTN_rmsd.xvg', 'r').readlines() #insert the path here

data = []

for line in datas[18:]:
    line = line.split()
    data.append([float(a) for a in line])

df_rmsd_prod5 = pd.DataFrame(data)
#df_nvt_eq.columns = df.iloc[0]
df_rmsd_prod5.columns=["Time(ps)","RMSD (nm)"]

# %%
df_rmsd_prod5

# %%
df_rmsd_prod5.plot(x="Time(ps)",y="RMSD (nm)", color=colors[4])

# %%
df_rmsd_prod5["RMSD (nm)"].mean()

# %% [markdown]
# ### Entropy calculation - with previous CodeEntropy release

# %%
tprfile5 = "rep_5/prod_BTN_only.tpr"
trrfile5 = "rep_5/prod_BTN_only.trr"
u5 = mda.Universe(tprfile5, trrfile5)

# %%
from CodeEntropy.ClassCollection import DataContainer as DC
dataContainer = DC.DataContainer (u5)
# Out:
# Number of atoms      : 31
# Number of frames     : 100001

# %%
num_frames = len(dataContainer.trajSnapshots)
print(num_frames)
# Out:
# 100001

# %%
dataContainer

# %%
from CodeEntropy.FunctionCollection import EntropyFunctions as EF
selection_string = "all"
axis_list = ["N2","C4","C2"]
outFile = None
moutFile = None
nmdFile = None
csv_out = None
tScale = 1.0
fScale = 1.0
temper = 298.0 
verbose = 3 
thread = 4

# %%
wm_entropyFF5, wm_entropyTT5 = EF.compute_entropy_whole_molecule_level (
    arg_hostDataContainer = dataContainer,
    arg_outFile = outFile,
    arg_selector = selection_string,
    arg_moutFile = moutFile,
    arg_nmdFile = nmdFile,
    arg_fScale = fScale,
    arg_tScale = tScale,
    arg_temper = temper,
    arg_verbose = verbose
)
print (f"wm_entropyFF = {wm_entropyFF5}")
print(f"wm_entropyTT = {wm_entropyTT5}")
# Out:
# ------------------------------------------------------------
#           Hierarchy level. --> Whole molecule <--
# ------------------------------------------------------------
# Total number of beads at the whole molecule level = 1
# Assigning Translation and Rotation Axes @ whole molecule level-> Done
# Updating Local coordinates-> Done
# Updating Local forces-> Done
# Updating Local torques-> Done
# Weighting forces and torques-> Done
# Updating the submatrices ...
# Finished updating submatrix FF
# Finished updating submatrix TT
# Done
# Generating Quadrants-> Done
# Diagonalizing-> Done
# Changing the units of eigen values to SI units-> Done
# Sorting spectrum in ascending order of frequencies-> Done
# Entropy values:
# FF Entropy (Whole mol level)             : 41.3996 J/mol/K
# TT Entropy (Whole mol level)             : 36.2397 J/mol/K
# wm_entropyFF = 41.399627205198534
# wm_entropyTT = 36.239730464659274

# %%
UA_entropyFF5, UA_entropyTT5, res_df = EF.compute_entropy_UA_level (
    arg_hostDataContainer = dataContainer,
    arg_outFile = outFile,
    arg_selector = selection_string,
    arg_moutFile = moutFile,
    arg_nmdFile = nmdFile,
    arg_fScale = fScale,
    arg_tScale = tScale,
    arg_temper = temper,
    arg_verbose = verbose,
    arg_axis_list = axis_list,
    arg_csv_out = csv_out,
)
print (f"UA_res_entropyFF = {UA_entropyFF5}")
print(f"UA_entropyTT = {UA_entropyTT5}")
# Out:
# ------------------------------------------------------------
#             Hierarchy level. --> United Atom <--
# ------------------------------------------------------------
# Working on resid : BTN1
# Total number of UA beads in residue BTN1 : 16
# Assigning Translation Axes at the UA level-> Done
# Assigning Rotational Axes at the UA level-> Done
# Updating Local forces-> Done
# Updating Local torques-> Done
# Weighting forces and torques-> Done
# Updating the submatrices ...
# Finished updating submatrix FF
# Finished updating submatrix TT
# Done
# Generating Quadrants-> Done
# A shape change has occured (48,48) -> (25, 25)
# Diagonalizing-> Done
# Changing the units of eigen values to SI units-> Done
# Sorting spectrum in ascending order of frequencies-> Done
# Entropy values:
# FF Entropy (UA for BTN1)                 : 109.9267 J/mol/K
# TT Entropy (UA for BTN1)                 : 15.3007 J/mol/K
#
#
#
# ------------------------------------------------------------
# ...

# %%
result_entropyAEM5 = EF.compute_topographical_entropy_AEM(
    arg_hostDataContainer = dataContainer,
    arg_selector = selection_string,
    arg_outFile = outFile,
    arg_verbose = verbose
)
print(f"result_entropyAEM = {result_entropyAEM5}")
# Out:
# ------------------------------------------------------------
# Topographical entropy of residue side chains
# computed using all the dihedrals with AEM method
# ------------------------------------------------------------
# ----------Working on resid : 1 (BTN)----------
# Found 14 exclusive dihedrals in residue BTN1
# Found 14 dihedrals which collectively acquire 117 unique conformers
# Residue Topographical Entropy from AEM (BTN 1) : 27.7857
# ------------------------------------------------------------
# Total Topog. Entropy (AEM)               :          27.786
# ------------------------------------------------------------
# result_entropyAEM = 27.785671200862843

# %%
total5 = wm_entropyFF5 + wm_entropyTT5 + UA_entropyFF5 + UA_entropyTT5 + result_entropyAEM5
print(f"Total Entropy = {total5} J/mol/K")
# Out:
# Total Entropy = 231.68248507659152 J/mol/K

# %%
wm_entropyFF_mean = (wm_entropyFF1+wm_entropyFF2+wm_entropyFF3+wm_entropyFF4+wm_entropyFF5)/5
print(wm_entropyFF_mean)
# Out:
# 41.390993638556274

# %%
wm_entropyTT_mean = (wm_entropyTT1+wm_entropyTT2+wm_entropyTT3+wm_entropyTT4+wm_entropyTT5)/5
print(wm_entropyTT_mean)
# Out:
# 36.224968874504576

# %%
UA_entropyFF_mean = (UA_entropyFF1+UA_entropyFF2+UA_entropyFF3+UA_entropyFF4+UA_entropyFF5)/5
print(UA_entropyFF_mean)
# Out:
# 110.76901892909311

# %%
UA_entropyTT_mean = (UA_entropyTT1+UA_entropyTT2+UA_entropyTT3+UA_entropyTT4+UA_entropyTT5)/5
print(UA_entropyTT_mean)
# Out:
# 15.127668943610285

# %%
AEM_entropy_mean = (result_entropyAEM1+result_entropyAEM2+result_entropyAEM3+result_entropyAEM4+result_entropyAEM5)/5
print(AEM_entropy_mean)
# Out:
# 27.68305970040739

# %%
total_mean= (total1+total2+total3+total4+total5)/5
print(total_mean)
# Out:
# 231.1957100861717

# %% [markdown]
# # Comparisons

# %%
time=np.array(df_prod1["Time(ps)"])
def comparison_plot(option,parameter,title):
    if option=='energy':
        array1=np.array(df_prod1[parameter])
        array2=np.array(df_prod2[parameter])
        array3=np.array(df_prod3[parameter])
        array4=np.array(df_prod4[parameter])
        array5=np.array(df_prod5[parameter])
    elif option=='rms':
        array1=np.array(df_rmsd_prod1[parameter])
        array2=np.array(df_rmsd_prod2[parameter])
        array3=np.array(df_rmsd_prod3[parameter])
        array4=np.array(df_rmsd_prod4[parameter])
        array5=np.array(df_rmsd_prod5[parameter])  
    fig = plt.figure()
    fig, ax = plt.subplots()
    ax.plot(time, array1, label='Rep. 1', color=colors[0])
    ax.plot(time, array2, label='Rep. 2', color=colors[1])
    ax.plot(time, array3, label='Rep. 3', color=colors[2])
    ax.plot(time, array4, label='Rep. 4', color=colors[3])
    ax.plot(time, array5, label='Rep. 5', color=colors[4])
    ax.set_xlabel('Time (ps)')
    ax.set_ylabel(parameter)
    ax.set_xlim([0,50000])
    ax.set_title(title)
    #ax.set_ylim([inf_limit,sup_limit])
    ax.legend()
    plt.savefig('ligand_ligand_rmsd.png')
    plt.close()
    plt.show()

# %%
comparison_plot('energy',"Potential Energy(kJ/mol)", "Potential Energy (kJ/mol) of ligand")

# %%
comparison_plot('energy',"Kinetic Energy(kJ/mol)",  "Kinetic Energy (kJ/mol) of ligand")

# %%
comparison_plot('energy',"Temperature(K)",  "Temperature (K)")

# %%
comparison_plot('energy',"Pressure (bar)","Pressure (bar)" )

# %%
comparison_plot('energy',"Density (kg/m^3)", "Density (kg/m^3)")

# %%
comparison_plot('rms', "RMSD (nm)", "Ligand RMSD (nm) in ligand simulation")
